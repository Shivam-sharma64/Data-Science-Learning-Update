# %%
import seaborn as sns

# %%
df=sns.load_dataset('iris')

# %%
sns.scatterplot(x=df.sepal_length,y=df.petal_length)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df.sepal_length,df.petal_length,'o')
plt.xlabel("sepal length")
plt.ylabel("petal length")
# Out:
# Text(0, 0.5, 'petal length')

# %%
plt.hist(df['sepal_length'])
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.displot(df['sepal_length'])

# %%
data=sns.load_dataset('tips')

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x='total_bill',y="tip",data=data)

# %%
data['smoker'].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
sns.relplot(x='total_bill',y='tip',data=data,hue='smoker')

# %%
sns.relplot(x='total_bill',y='tip',data=data,style='smoker')

# %%
sns.relplot(x='total_bill',y='tip',data=data,style='smoker',hue='time')

# %%
sns.relplot(x='total_bill',y='tip',data=data,style='size')

# %%
sns.relplot(x='total_bill',y='tip',kind='line',data=data)

# %%
sns.relplot(x='total_bill',y='tip',col='time',data=data)
