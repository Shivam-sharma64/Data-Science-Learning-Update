# %%
s="shivam"

# %%
s=iter(s)

# %%
next(s)
# Out:
# 's'

# %%
next(s)
# Out:
# 'h'

# %%
next(s)
# Out:
# 'i'

# %%
l=[1,2,3,4,5,6]

# %%
l=iter(l)

# %%
next(l)
# Out:
# 1

# %%
next(l)
# Out:
# 2

# %%
next(l)
# Out:
# 3

# %%
next(l)
# Out:
# 4

# %%
next(l)
# Out:
# 5

# %%
next(l)
# Out:
# 6

# %%
next(l)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 next(l)
#
# StopIteration:

# %%
a=56

# %%
a=iter(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 a=iter(a)
#
# TypeError: 'int' object is not iterable

# %%
t=(23,54,32,54)

# %%
t=iter(t)

# %%
next(t)
# Out:
# 23

# %%
range(45)
# Out:
# range(0, 45)

# %%
a=range(0,45,3)

# %%
next(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 next(a)
#
# TypeError: 'range' object is not an iterator

# %%
a=iter(a)

# %%
next(a)
# Out:
# 0

# %%
next(a)
# Out:
# 3

# %%
next(a)
# Out:
# 6

# %%
next(a)
# Out:
# 9

# %%
next(a)
# Out:
# 12

# %%
next(a)
# Out:
# 15

# %%
next(a)
# Out:
# 18

# %%
next(a)
# Out:
# 21

# %%
l=[]
def gencube(n):
    for i in range(n):
        l.append(i**3)
        print(i**3)

# %%
gencube(60)
# Out:
# <generator object gencube at 0x000001FD49887850>

# %%
l
# Out:
# [0,
#  1,
#  8,
#  27,
#  64,
#  125,
#  0,
#  1,
#  8,
#  27,
#  64,
#  125,
#  216,
#  343,
#  512,
#  729,
#  1000,
#  1331,
#  1728,
#  2197,
#  2744,
#  3375,
#  4096,
#  4913,
#  5832,
#  6859,
#  8000,
#  9261,
#  10648,
#  12167,
#  13824,
#  15625,
#  17576,
#  19683,
#  21952,
#  24389,
#  27000,
#  29791,
#  32768,
#  35937,
#  39304,
#  42875,
#  46656,
#  50653,
#  54872,
#  59319,
#  64000,
#  68921,
#  74088,
#  79507,
#  85184,
#  91125,
#  97336,
#  103823,
#  110592,
#  117649,
#  125000,
#  132651,
#  140608,
#  148877,
#  157464,
#  166375,
#  175616,
#  185193,
#  195112,
#  205379,
#  216000,
#  226981,
#  238328,
#  250047,
#  262144,
#  274625,
#  287496,
#  300763,
#  314432,
#  328509,
#  343000,
#  357911,
#  373248,
#  389017,
#  405224,
#  421875,
#  438976,
#  456533,
#  474552,
#  493039,
#  512000,
#  531441,
#  551368,
#  571787,
#  592704,
#  614125,
#  636056,
#  658503,
#  681472,
#  704969,
#  729000,
#  753571,
#  778688,
#  804357,
#  830584,
# ...

# %%
l=[]
def gencube(n):
    for i in range(n):
        yield i**3

#yield used to create a func to a generator

# %%
gencube(23)
# Out:
# <generator object gencube at 0x000001FD49886F60>

# %%
l
# Out:
# []

# %%
def fib(n):
    a=1
    b=1
    for i in range(n):
        yield a,i
        a,b=b,a+b

# %%
for i in fib(6):
    print(i)
# Out:
# (1, 0)
# (1, 1)
# (2, 2)
# (3, 3)
# (5, 4)
# (8, 5)

# %%
print("something on console")
# Out:
# something on console

# %%
f=open("{test.text","w")

# %%
pwd()
# Out:
# 'C:\\Users\\ASUS\\data science'

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is D8D8-9A4A
#
#  Directory of C:\Users\ASUS\data science
#
# 20-04-2025  10:30    <DIR>          .
# 20-04-2025  10:01    <DIR>          ..
# 20-04-2025  10:02    <DIR>          .ipynb_checkpoints
# 20-04-2025  10:27                 0 {test.text
# 20-04-2025  10:30            37,796 iterator generator.ipynb
#                2 File(s)         37,796 bytes
#                3 Dir(s)  85,013,786,624 bytes free

# %%
f.write("this is my first while operation and we are learning file opening in data science")
# Out:
# 81

# %%
f=open('{test.text','r')

# %%
f.read()
# Out:
# 'this is my first while operation and we are learning file opening in data science'

# %%
f.close()

# %%
f=open('{test.text','r')

# %%
f.seek(5)
# Out:
# 5

# %%
f.tell()
# Out:
# 5

# %%
f.read()
# Out:
# 'is my first while operation and we are learning file opening in data science'

# %%
f.close()

# %%
f=open('{test.text','r')

# %%
f.readline()
# Out:
# 'this is my first while operation and we are learning file opening in data science'

# %%
f.readlines()
# Out:
# []

# %%
f.seek(0)
# Out:
# 0

# %%
f.readlines()
# Out:
# ['this is my first while operation and we are learning file opening in data science']

# %%
f=open('{test.text',"w")

# %%
f.write("""1st line
df
fg
fg
fg
fg
fg
fg
fg
fg""")
# Out:
# 35

# %%
f=open('{test.text','r')

# %%
f.read()
# Out:
# '1st line\ndf\nfg\nfg\nfg\nfg\nfg\nfg\nfg\nfgious paragraphoi.\nA paragraphos (Ancient Greek: '

# %%
f.readline()
# Out:
# ''

# %%
f.readline()
# Out:
# ''

# %%
f.seek(0)
# Out:
# 0

# %%
f.readline()
# Out:
# '1st line\n'

# %%
f.readline()
# Out:
# 'df\n'

# %%
f.readline()
# Out:
# 'fg\n'

# %%
f.readline()
# Out:
# 'fg\n'

# %%
f.readline()
# Out:
# 'fg\n'

# %%
f.seek(0)
# Out:
# 0

# %%
f.readlines()
# Out:
# ['1st line\n',
#  'df\n',
#  'fg\n',
#  'fg\n',
#  'fg\n',
#  'fg\n',
#  'fg\n',
#  'fg\n',
#  'fg\n',
#  'fgious paragraphoi.\n',
#  'A paragraphos (Ancient Greek: ']

# %%
f=open('{test.text','r+')
for line in f:
    print(line,end="")
# Out:
# 1st line
# df
# fg
# fg
# fg
# fg
# fg
# fg
# fg
# fgious paragraphoi.
# A paragraphos (Ancient Greek:

# %%
os.listdir
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[135], line 1
# ----> 1 os.listdir
#
# NameError: name 'os' is not defined

# %%
import os

# %%
pwd()
# Out:
# 'C:\\Users\\ASUS\\data science'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'iterator generator.ipynb', '{test.text']

# %%
f=open('test1.txt','w')
f.write("file1 is here")
# Out:
# 13

# %%
f=open('test2.txt','w')
f.write("file2 is here")
# Out:
# 13

# %%
f=open('test3.txt','w')
f.write("file3 is here")
# Out:
# 13

# %%
f=open('test3.txt','r')
f.read()
# Out:
# 'file3 is here'

# %%
list_of_files=os.listdir()
l=[]
for i in list_of_files:
    if i.lower().endswith('txt'):
        with open(i,'r') as f:
            content=f.read()
            print(content)
            l.append(content)
# Out:
# file1 is here
# file2 is here
# file3 is here

# %%
l
# Out:
# ['file1 is here', 'file2 is here', 'file3 is here']

# %%
for i in list_of_files:
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
