# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
data=pd.DataFrame(np.random.randn(1000))

# %%
data.plot(figsize=(20,10))
# Out:
# <Axes: >

# %%
df=pd.read_csv("https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv")

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.plot(figsize=(20,10))
# Out:
# <Axes: >

# %%
df.iloc[5:11].plot(kind='bar',figsize=(20,10))
# Out:
# <Axes: >

# %%
df.iloc[5:11]
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 8            4.4          2.9           1.4          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa

# %%
df.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['sepal.length'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.hist(figsize=(20,10),color='r',alpha=0.7)
# Out:
# array([[<Axes: title={'center': 'sepal.length'}>,
#         <Axes: title={'center': 'sepal.width'}>],
#        [<Axes: title={'center': 'petal.length'}>,
#         <Axes: title={'center': 'petal.width'}>]], dtype=object)

# %%
df.plot(kind='box',color={"boxes":"r"})
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.plot(kind="area",figsize=(20,10),stacked=False)
# Out:
# <Axes: >

# %%
df.plot(figsize=(20,10))
# Out:
# <Axes: >

# %%
df.plot.scatter(x='sepal.length',y='petal.length')
# Out:
# <Axes: xlabel='sepal.length', ylabel='petal.length'>

# %%
df.plot.scatter(x='sepal.length',y='petal.length',c='sepal.width',s=60)
# Out:
# <Axes: xlabel='sepal.length', ylabel='petal.length'>

# %%
df.plot.hexbin(x='sepal.length',y='petal.length',gridsize=10,C='sepal.width')
# Out:
# <Axes: xlabel='sepal.length', ylabel='petal.length'>

# %%
df1=df.drop(columns='variety').iloc[0]

# %%
df1.plot(kind='pie')
# Out:
# <Axes: ylabel='0'>

# %%
df1
# Out:
# sepal.length    5.1
# sepal.width     3.5
# petal.length    1.4
# petal.width     0.2
# Name: 0, dtype: float64

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install cufflinks
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68721 sha256=2af67e40f683127ffa3b3813a181abb7e202d46fef3c6747d35117715d6102ca
#   Stored in directory: c:\users\asus\appdata\local\pip\cache\wheels\c0\d9\70\372130dacf508192607c1a7359c7bf0656b1a3b79f6cf66f7a
# Successfully built cufflinks
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install chart_studio
# Out:
# ...
#
# ...

# %%
import cufflinks as cf

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.iplot()

# %%
df.iplot(x='sepal.length',y='petal.length',mode='markers')

# %%
df.iplot(kind='scatter',mode='markers',size=3)

# %%
df.iplot(kind='bubble',x='sepal.length',y='petal.length',size='sepal.width')

# %%
df.scatter_matrix()

# %%
df.head().iplot(kind='scatter3d',x='sepal.length',y='petal.length',z='sepal.width')

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
